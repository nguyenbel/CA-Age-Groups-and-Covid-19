# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2
from datetime import datetime
import math
from tabulate import tabulate # print dataframes as tables
import matplotlib.dates as mdates

# %% [markdown]
# Covid Ages Data from https://data.ca.gov/dataset/covid-19-cases/resource/926fd08f-cc91-4828https://data.ca.gov/dataset/covid-19-cases/resource/926fd08f-cc91-4828-af38-bd45de97f8c3-af38-bd45de97f8c3

# %%
# read covid age demographics
covid_ages = pd.read_csv('data/case_demographics_age.csv')
covid_ages.head()

# lots of missing data at beginning -> perhaps because nothing to compare it to
# Out:
#       age_group  totalpositive        date  case_percent  deaths  \
# 0          0-17            120  2020-04-02           NaN     NaN
# 1         18-49           5302  2020-04-02           NaN     NaN
# 2         50-64           2879  2020-04-02           NaN     NaN
# 3  65 and Older           2342  2020-04-02           NaN     NaN
# 4       Unknown             58  2020-04-02           NaN     NaN
#
#    deaths_percent  ca_percent
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN

# %%
covid_ages.info()
#1235 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age_group       1235 non-null   object
#  1   totalpositive   1235 non-null   int64
#  2   date            1235 non-null   object
#  3   case_percent    1135 non-null   float64
#  4   deaths          1135 non-null   float64
#  5   deaths_percent  1135 non-null   float64
#  6   ca_percent      1125 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 67.7+ KB

# %%
covid_ages['age_group'].unique()
# Out:
# array(['0-17', '18-49', '50-64', '65 and Older', 'Unknown', '65+',
#        'Missing'], dtype=object)

# %% [markdown]
# Covid Data from https://data.ca.gov/dataset/covid-19-cases/resource/926fd08f-cc91-4828-af38-bd45de97f8c3

# %%
covid_cases = pd.read_csv('data/statewide_cases.csv')
covid_cases.head()
# Out:
#         county  totalcountconfirmed  totalcountdeaths  newcountconfirmed  \
# 0  Santa Clara                151.0               6.0                151
# 1  Santa Clara                183.0               8.0                 32
# 2  Santa Clara                246.0               8.0                 63
# 3  Santa Clara                269.0              10.0                 23
# 4  Santa Clara                284.0              13.0                 15
#
#    newcountdeaths        date
# 0               6  2020-03-18
# 1               2  2020-03-19
# 2               0  2020-03-20
# 3               2  2020-03-21
# 4               3  2020-03-22

# %%
covid_cases.info()
#15665 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15665 entries, 0 to 15664
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   county               15665 non-null  object
#  1   totalcountconfirmed  15662 non-null  float64
#  2   totalcountdeaths     15663 non-null  float64
#  3   newcountconfirmed    15665 non-null  int64
#  4   newcountdeaths       15665 non-null  int64
#  5   date                 15665 non-null  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 734.4+ KB

# %% [markdown]
# Notes about what is observed from the data:
#
# - Both have the same Date Format, which is YYYY/MM/DD Time, so we can potentially join on date
# - The covid_cases is sorted by date and grouped by county, but the covid_ages doesn't show us the counties. We would need to sum totalcountconfirmed in covid_cases grouped by dates before joining and comparing the proportions; We will also probably need to do that for the age groups...
# - Unknown and missing age group in covid_ages; what are they? How should we account for them?

# %%
grouped_covid_cases = covid_cases.groupby('date')[['totalcountconfirmed', 'newcountconfirmed']].sum()
grouped_covid_cases
# Out:
#             totalcountconfirmed  newcountconfirmed
# date
# 2020-03-18                675.0                675
# 2020-03-19               1006.0                331
# 2020-03-20               1224.0                218
# 2020-03-21               1468.0                244
# 2020-03-22               1733.0                265
# ...                         ...                ...
# 2020-11-30            1225189.0              12221
# 2020-12-01            1245948.0              20759
# 2020-12-02            1264539.0              18591
# 2020-12-03            1286557.0              22018
# 2020-12-04            1311625.0              25068
#
# [262 rows x 2 columns]

# %%
grouped_covid_ages = covid_ages.groupby(['date','age_group'])['totalpositive'].sum()
grouped_covid_ages
# Out:
# date        age_group
# 2020-04-02  0-17               120
#             18-49             5302
#             50-64             2879
#             65 and Older      2342
#             Unknown             58
#                              ...
# 2020-12-04  0-17            147807
#             18-49           780365
#             50-64           246393
#             65+             135981
#             Missing           1079
# Name: totalpositive, Length: 1235, dtype: int64

# %%
# change grouped series to dataframe and reset index to get
# age group and date out of index
grouped_covid_ages = grouped_covid_ages.to_frame()
grouped_covid_ages = grouped_covid_ages.reset_index()
grouped_covid_cases = grouped_covid_cases.reset_index()

# %%
grouped_covid_ages
# Out:
#             date     age_group  totalpositive
# 0     2020-04-02          0-17            120
# 1     2020-04-02         18-49           5302
# 2     2020-04-02         50-64           2879
# 3     2020-04-02  65 and Older           2342
# 4     2020-04-02       Unknown             58
# ...          ...           ...            ...
# 1230  2020-12-04          0-17         147807
# 1231  2020-12-04         18-49         780365
# 1232  2020-12-04         50-64         246393
# 1233  2020-12-04           65+         135981
# 1234  2020-12-04       Missing           1079
#
# [1235 rows x 3 columns]

# %%
print(grouped_covid_ages[grouped_covid_ages['age_group'] == '65 and Older'].to_markdown())
print(grouped_covid_ages[grouped_covid_ages['age_group'] == '65+'].to_markdown())
# 65 and Older changed to 65+ after 4/28/2020
# Rename 65+ to 65 and Older
grouped_covid_ages = grouped_covid_ages.replace('65+', '65 and Older')
# Out:
# |     | date       | age_group    |   totalpositive |
# |----:|:-----------|:-------------|----------------:|
# |   3 | 2020-04-02 | 65 and Older |            2342 |
# |   8 | 2020-04-03 | 65 and Older |            2660 |
# |  13 | 2020-04-04 | 65 and Older |            2966 |
# |  18 | 2020-04-05 | 65 and Older |            3129 |
# |  23 | 2020-04-06 | 65 and Older |            3516 |
# |  28 | 2020-04-07 | 65 and Older |            3751 |
# |  33 | 2020-04-08 | 65 and Older |            4056 |
# |  38 | 2020-04-09 | 65 and Older |            4335 |
# |  43 | 2020-04-10 | 65 and Older |            4561 |
# |  48 | 2020-04-11 | 65 and Older |            4870 |
# |  53 | 2020-04-12 | 65 and Older |            5036 |
# |  58 | 2020-04-13 | 65 and Older |            5320 |
# |  63 | 2020-04-14 | 65 and Older |            5605 |
# |  68 | 2020-04-15 | 65 and Older |            6051 |
# |  73 | 2020-04-16 | 65 and Older |            6360 |
# |  78 | 2020-04-17 | 65 and Older |            6729 |
# |  83 | 2020-04-18 | 65 and Older |            7071 |
# |  88 | 2020-04-19 | 65 and Older |            7267 |
# |  93 | 2020-04-20 | 65 and Older |            7650 |
# |  98 | 2020-04-21 | 65 and Older |            8035 |
# | 103 | 2020-04-22 | 65 and Older |            8401 |
# | 108 | 2020-04-23 | 65 and Older |            8832 |
# | 113 | 2020-04-24 | 65 and Older |            9256 |
# | 118 | 2020-04-25 | 65 and Older |            9512 |
# | 123 | 2020-04-26 | 65 and Older |            9824 |
# | 128 | 2020-04-27 | 65 and Older |           10086 |
# |      | date       | age_group   |   totalpositive |
# |-----:|:-----------|:------------|----------------:|
# |  133 | 2020-04-28 | 65+         |           10413 |
# |  138 | 2020-04-29 | 65+         |           10906 |
# |  143 | 2020-04-30 | 65+         |           11256 |
# |  148 | 2020-05-01 | 65+         |           11547 |
# |  153 | 2020-05-02 | 65+         |           11860 |
# |  158 | 2020-05-03 | 65+         |           12098 |
# |  163 | 2020-05-04 | 65+         |           12425 |
# |  168 | 2020-05-05 | 65+         |           12842 |
# |  173 | 2020-05-06 | 65+         |           13194 |
# |  178 | 2020-05-07 | 65+         |           13580 |
# |  183 | 2020-05-08 | 65+         |           13948 |
# |  188 | 2020-05-09 | 65+         |           14290 |
# |  193 | 2020-05-10 | 65+         |           14597 |
# |  198 | 2020-05-11 | 65+         |           14845 |
# |  203 | 2020-05-12 | 65+         |           15098 |
# |  208 | 2020-05-13 | 65+         |           15498 |
# |  213 | 2020-05-14 | 65+         |           15725 |
# |  218 | 2020-05-15 | 65+         |           16101 |
# |  223 | 2020-05-16 | 65+         |           16489 |
# |  228 | 2020-05-17 | 65+         |           16727 |
# |  233 | 2020-05-18 | 65+         |           16920 |
# |  238 | 2020-05-19 | 65+         |           17232 |
# |  243 | 2020-05-20 | 65+         |           17513 |
# |  248 | 2020-05-21 | 65+         |           17864 |
# |  253 | 2020-05-22 | 65+         |           18164 |
# |  258 | 2020-05-23 | 65+         |           18424 |
# |  263 | 2020-05-24 | 65+         |           18670 |
# |  268 | 2020-05-25 | 65+         |           18898 |
# |  273 | 2020-05-26 | 65+         |           19095 |
# |  278 | 2020-05-27 | 65+         |           19462 |
# |  283 | 2020-05-28 | 65+         |           19773 |
# |  288 | 2020-05-29 | 65+         |           20073 |
# |  293 | 2020-05-30 | 65+         |           20455 |
# |  298 | 2020-05-31 | 65+         |           20792 |
# |  303 | 2020-06-01 | 65+         |           21054 |
# |  308 | 2020-06-02 | 65+         |           21354 |
# |  313 | 2020-06-03 | 65+         |           21595 |
# |  318 | 2020-06-04 | 65+         |           22002 |
# |  323 | 2020-06-05 | 65+         |           22365 |
# |  328 | 2020-06-06 | 65+         |           22704 |
# |  333 | 2020-06-07 | 65+         |           22939 |
# |  338 | 2020-06-08 | 65+         |           23154 |
# |  343 | 2020-06-09 | 65+         |           23469 |
# |  348 | 2020-06-10 | 65+         |           23806 |
# |  353 | 2020-06-11 | 65+         |           24043 |
# |  358 | 2020-06-12 | 65+         |           24403 |
# |  363 | 2020-06-13 | 65+         |           24762 |
# |  368 | 2020-06-14 | 65+         |           24981 |
# |  373 | 2020-06-15 | 65+         |           25109 |
# |  378 | 2020-06-16 | 65+         |           25503 |
# |  383 | 2020-06-17 | 65+         |           25911 |
# |  388 | 2020-06-18 | 65+         |           26385 |
# |  393 | 2020-06-19 | 65+         |           26741 |
# |  398 | 2020-06-20 | 65+         |           27173 |
# |  403 | 2020-06-21 | 65+         |           27456 |
# |  408 | 2020-06-22 | 65+         |           27864 |
# |  413 | 2020-06-23 | 65+         |           28528 |
# |  418 | 2020-06-24 | 65+         |           29048 |
# |  423 | 2020-06-25 | 65+         |           29544 |
# |  428 | 2020-06-26 | 65+         |           30007 |
# |  433 | 2020-06-27 | 65+         |           30333 |
# |  438 | 2020-06-28 | 65+         |           30893 |
# |  443 | 2020-06-29 | 65+         |           31379 |
# |  448 | 2020-06-30 | 65+         |           32145 |
# |  453 | 2020-07-01 | 65+         |           32815 |
# |  458 | 2020-07-02 | 65+         |           33445 |
# |  463 | 2020-07-03 | 65+         |           34055 |
# |  468 | 2020-07-04 | 65+         |           34493 |
# |  473 | 2020-07-05 | 65+         |           35441 |
# |  478 | 2020-07-06 | 65+         |           35957 |
# |  483 | 2020-07-07 | 65+         |           36911 |
# |  488 | 2020-07-08 | 65+         |           37586 |
# |  493 | 2020-07-09 | 65+         |           38346 |
# |  498 | 2020-07-10 | 65+         |           39039 |
# |  503 | 2020-07-11 | 65+         |           39776 |
# |  508 | 2020-07-12 | 65+         |           40473 |
# |  513 | 2020-07-13 | 65+         |           41080 |
# |  518 | 2020-07-14 | 65+         |           42007 |
# |  523 | 2020-07-15 | 65+         |           42748 |
# |  528 | 2020-07-16 | 65+         |           43550 |
# |  533 | 2020-07-17 | 65+         |           44297 |
# |  538 | 2020-07-18 | 65+         |           45166 |
# |  543 | 2020-07-19 | 65+         |           45759 |
# |  548 | 2020-07-20 | 65+         |           46495 |
# |  553 | 2020-07-21 | 65+         |           47673 |
# |  558 | 2020-07-22 | 65+         |           48744 |
# |  563 | 2020-07-23 | 65+         |           49648 |
# |  568 | 2020-07-24 | 65+         |           50518 |
# |  573 | 2020-07-25 | 65+         |           51190 |
# |  578 | 2020-07-26 | 65+         |           51772 |
# |  583 | 2020-07-27 | 65+         |           52302 |
# |  588 | 2020-07-28 | 65+         |           53138 |
# |  593 | 2020-07-29 | 65+         |           54039 |
# |  598 | 2020-07-30 | 65+         |           54743 |
# |  603 | 2020-07-31 | 65+         |           55360 |
# |  608 | 2020-08-01 | 65+         |           56206 |
# |  613 | 2020-08-02 | 65+         |           56786 |
# |  618 | 2020-08-03 | 65+         |           57247 |
# |  623 | 2020-08-04 | 65+         |           57847 |
# |  628 | 2020-08-05 | 65+         |           58458 |
# |  633 | 2020-08-06 | 65+         |           59282 |
# |  638 | 2020-08-07 | 65+         |           59954 |
# |  643 | 2020-08-08 | 65+         |           60829 |
# |  648 | 2020-08-09 | 65+         |           61464 |
# |  653 | 2020-08-10 | 65+         |           62506 |
# |  658 | 2020-08-11 | 65+         |           63617 |
# |  663 | 2020-08-12 | 65+         |           64298 |
# |  668 | 2020-08-13 | 65+         |           65116 |
# |  673 | 2020-08-14 | 65+         |           66403 |
# |  678 | 2020-08-15 | 65+         |           67168 |
# |  683 | 2020-08-16 | 65+         |           67816 |
# |  688 | 2020-08-17 | 65+         |           68211 |
# |  693 | 2020-08-18 | 65+         |           68806 |
# |  698 | 2020-08-19 | 65+         |           69380 |
# |  703 | 2020-08-20 | 65+         |           69957 |
# |  708 | 2020-08-21 | 65+         |           70688 |
# |  713 | 2020-08-22 | 65+         |           71455 |
# |  718 | 2020-08-23 | 65+         |           71901 |
# |  723 | 2020-08-24 | 65+         |           72358 |
# |  728 | 2020-08-25 | 65+         |           72988 |
# |  733 | 2020-08-26 | 65+         |           73489 |
# |  738 | 2020-08-27 | 65+         |           74124 |
# |  743 | 2020-08-28 | 65+         |           74665 |
# |  748 | 2020-08-29 | 65+         |           75284 |
# |  753 | 2020-08-30 | 65+         |           75729 |
# |  758 | 2020-08-31 | 65+         |           76098 |
# |  763 | 2020-09-01 | 65+         |           76511 |
# |  768 | 2020-09-02 | 65+         |           77191 |
# |  773 | 2020-09-03 | 65+         |           77807 |
# |  778 | 2020-09-04 | 65+         |           78262 |
# |  783 | 2020-09-05 | 65+         |           78740 |
# |  788 | 2020-09-06 | 65+         |           79046 |
# |  793 | 2020-09-07 | 65+         |           79301 |
# |  798 | 2020-09-08 | 65+         |           79476 |
# |  803 | 2020-09-09 | 65+         |           79803 |
# |  808 | 2020-09-10 | 65+         |           80183 |
# |  813 | 2020-09-11 | 65+         |           80630 |
# |  818 | 2020-09-12 | 65+         |           81053 |
# |  823 | 2020-09-13 | 65+         |           81333 |
# |  828 | 2020-09-14 | 65+         |           81506 |
# |  833 | 2020-09-15 | 65+         |           81822 |
# |  838 | 2020-09-16 | 65+         |           82148 |
# |  843 | 2020-09-17 | 65+         |           82521 |
# |  848 | 2020-09-18 | 65+         |           82954 |
# |  853 | 2020-09-19 | 65+         |           83379 |
# |  858 | 2020-09-20 | 65+         |           83683 |
# |  863 | 2020-09-21 | 65+         |           83936 |
# |  868 | 2020-09-22 | 65+         |           84312 |
# |  873 | 2020-09-23 | 65+         |           84659 |
# |  878 | 2020-09-24 | 65+         |           85007 |
# |  883 | 2020-09-25 | 65+         |           85434 |
# |  888 | 2020-09-26 | 65+         |           85776 |
# |  893 | 2020-09-27 | 65+         |           86053 |
# |  898 | 2020-09-28 | 65+         |           86274 |
# |  903 | 2020-09-29 | 65+         |           86652 |
# |  908 | 2020-09-30 | 65+         |           86965 |
# |  913 | 2020-10-01 | 65+         |           87371 |
# |  918 | 2020-10-02 | 65+         |           87546 |
# |  923 | 2020-10-03 | 65+         |           88023 |
# |  928 | 2020-10-04 | 65+         |           88296 |
# |  933 | 2020-10-05 | 65+         |           88464 |
# |  938 | 2020-10-06 | 65+         |           88764 |
# |  943 | 2020-10-07 | 65+         |           89114 |
# |  948 | 2020-10-08 | 65+         |           89535 |
# |  953 | 2020-10-09 | 65+         |           89927 |
# |  958 | 2020-10-10 | 65+         |           90249 |
# |  963 | 2020-10-11 | 65+         |           90571 |
# |  968 | 2020-10-12 | 65+         |           90787 |
# |  973 | 2020-10-13 | 65+         |           91051 |
# |  978 | 2020-10-14 | 65+         |           91359 |
# |  983 | 2020-10-15 | 65+         |           91697 |
# |  988 | 2020-10-16 | 65+         |           92027 |
# |  993 | 2020-10-17 | 65+         |           92326 |
# |  998 | 2020-10-18 | 65+         |           92643 |
# | 1003 | 2020-10-19 | 65+         |           92952 |
# | 1008 | 2020-10-20 | 65+         |           93333 |
# | 1013 | 2020-10-21 | 65+         |           93662 |
# | 1018 | 2020-10-22 | 65+         |           94321 |
# | 1023 | 2020-10-23 | 65+         |           94882 |
# | 1028 | 2020-10-24 | 65+         |           95336 |
# | 1033 | 2020-10-25 | 65+         |           95584 |
# | 1038 | 2020-10-26 | 65+         |           95901 |
# | 1043 | 2020-10-27 | 65+         |           96305 |
# | 1048 | 2020-10-28 | 65+         |           96800 |
# | 1053 | 2020-10-29 | 65+         |           97247 |
# | 1058 | 2020-10-30 | 65+         |           97764 |
# | 1063 | 2020-10-31 | 65+         |           98240 |
# | 1068 | 2020-11-01 | 65+         |           98643 |
# | 1073 | 2020-11-02 | 65+         |           99065 |
# | 1078 | 2020-11-03 | 65+         |           99592 |
# | 1083 | 2020-11-04 | 65+         |          100004 |
# | 1088 | 2020-11-05 | 65+         |          100643 |
# | 1093 | 2020-11-06 | 65+         |          101279 |
# | 1098 | 2020-11-07 | 65+         |          101922 |
# | 1103 | 2020-11-08 | 65+         |          102592 |
# | 1108 | 2020-11-09 | 65+         |          103063 |
# | 1113 | 2020-11-10 | 65+         |          103745 |
# | 1118 | 2020-11-11 | 65+         |          104403 |
# | 1123 | 2020-11-12 | 65+         |          105031 |
# | 1128 | 2020-11-13 | 65+         |          106013 |
# | 1133 | 2020-11-14 | 65+         |          107074 |
# | 1138 | 2020-11-15 | 65+         |          107973 |
# | 1143 | 2020-11-16 | 65+         |          108766 |
# | 1148 | 2020-11-17 | 65+         |          109763 |
# | 1153 | 2020-11-18 | 65+         |          110871 |
# | 1158 | 2020-11-19 | 65+         |          112026 |
# | 1163 | 2020-11-20 | 65+         |          113542 |
# | 1168 | 2020-11-21 | 65+         |          114971 |
# | 1173 | 2020-11-22 | 65+         |          115905 |
# | 1178 | 2020-11-23 | 65+         |          117343 |
# | 1183 | 2020-11-24 | 65+         |          119130 |
# | 1188 | 2020-11-25 | 65+         |          120544 |
# | 1193 | 2020-11-26 | 65+         |          121832 |
# | 1198 | 2020-11-27 | 65+         |          123005 |
# | 1203 | 2020-11-28 | 65+         |          124744 |
# | 1208 | 2020-11-29 | 65+         |          126255 |
# | 1213 | 2020-11-30 | 65+         |          127432 |
# | 1218 | 2020-12-01 | 65+         |          129548 |
# | 1223 | 2020-12-02 | 65+         |          131495 |
# | 1228 | 2020-12-03 | 65+         |          133635 |
# | 1233 | 2020-12-04 | 65+         |          135981 |

# %%
# Taking out the missing data (Unknown and Missing age groups)
# Unknown age group renamed to Missing after 6/01/2020
print(grouped_covid_ages[grouped_covid_ages['age_group'] == 'Unknown'].to_markdown())
print(grouped_covid_ages[grouped_covid_ages['age_group'] == 'Missing'].to_markdown())
# Replace Unknown with Missing age group name
grouped_covid_ages = grouped_covid_ages.replace('Unknown', 'Missing')
# Out:
# |     | date       | age_group   |   totalpositive |
# |----:|:-----------|:------------|----------------:|
# |   4 | 2020-04-02 | Unknown     |              58 |
# |   9 | 2020-04-03 | Unknown     |              59 |
# |  14 | 2020-04-04 | Unknown     |              49 |
# |  19 | 2020-04-05 | Unknown     |              51 |
# |  24 | 2020-04-06 | Unknown     |              55 |
# |  29 | 2020-04-07 | Unknown     |              56 |
# |  34 | 2020-04-08 | Unknown     |              59 |
# |  39 | 2020-04-09 | Unknown     |              52 |
# |  44 | 2020-04-10 | Unknown     |              49 |
# |  49 | 2020-04-11 | Unknown     |              54 |
# |  54 | 2020-04-12 | Unknown     |              58 |
# |  59 | 2020-04-13 | Unknown     |              62 |
# |  64 | 2020-04-14 | Unknown     |              69 |
# |  69 | 2020-04-15 | Unknown     |              79 |
# |  74 | 2020-04-16 | Unknown     |              64 |
# |  79 | 2020-04-17 | Unknown     |              67 |
# |  84 | 2020-04-18 | Unknown     |              72 |
# |  89 | 2020-04-19 | Unknown     |              63 |
# |  94 | 2020-04-20 | Unknown     |              66 |
# |  99 | 2020-04-21 | Unknown     |              67 |
# | 104 | 2020-04-22 | Unknown     |              84 |
# | 109 | 2020-04-23 | Unknown     |              81 |
# | 114 | 2020-04-24 | Unknown     |              88 |
# | 119 | 2020-04-25 | Unknown     |              95 |
# | 124 | 2020-04-26 | Unknown     |              85 |
# | 129 | 2020-04-27 | Unknown     |              86 |
# | 134 | 2020-04-28 | Unknown     |              75 |
# | 139 | 2020-04-29 | Unknown     |              72 |
# | 144 | 2020-04-30 | Unknown     |              80 |
# | 149 | 2020-05-01 | Unknown     |              82 |
# | 154 | 2020-05-02 | Unknown     |              87 |
# | 159 | 2020-05-03 | Unknown     |              90 |
# | 164 | 2020-05-04 | Unknown     |              92 |
# | 169 | 2020-05-05 | Unknown     |              94 |
# | 174 | 2020-05-06 | Unknown     |              88 |
# | 179 | 2020-05-07 | Unknown     |              98 |
# | 184 | 2020-05-08 | Unknown     |              99 |
# | 189 | 2020-05-09 | Unknown     |              98 |
# | 194 | 2020-05-10 | Unknown     |              91 |
# | 199 | 2020-05-11 | Unknown     |              93 |
# | 204 | 2020-05-12 | Unknown     |             103 |
# | 209 | 2020-05-13 | Unknown     |             111 |
# | 214 | 2020-05-14 | Unknown     |             113 |
# | 219 | 2020-05-15 | Unknown     |             109 |
# | 224 | 2020-05-16 | Unknown     |             109 |
# | 229 | 2020-05-17 | Unknown     |             106 |
# | 234 | 2020-05-18 | Unknown     |             105 |
# | 239 | 2020-05-19 | Unknown     |             109 |
# | 244 | 2020-05-20 | Unknown     |             113 |
# | 249 | 2020-05-21 | Unknown     |             118 |
# | 254 | 2020-05-22 | Unknown     |             125 |
# | 259 | 2020-05-23 | Unknown     |             132 |
# | 264 | 2020-05-24 | Unknown     |             137 |
# | 269 | 2020-05-25 | Unknown     |             135 |
# | 274 | 2020-05-26 | Unknown     |             149 |
# | 279 | 2020-05-27 | Unknown     |             155 |
# | 284 | 2020-05-28 | Unknown     |             159 |
# | 289 | 2020-05-29 | Unknown     |             169 |
# | 294 | 2020-05-30 | Unknown     |             172 |
# | 299 | 2020-05-31 | Unknown     |             177 |
# |      | date       | age_group   |   totalpositive |
# |-----:|:-----------|:------------|----------------:|
# |  304 | 2020-06-01 | Missing     |             177 |
# |  309 | 2020-06-02 | Missing     |             178 |
# |  314 | 2020-06-03 | Missing     |             179 |
# |  319 | 2020-06-04 | Missing     |             181 |
# |  324 | 2020-06-05 | Missing     |             185 |
# |  329 | 2020-06-06 | Missing     |             193 |
# |  334 | 2020-06-07 | Missing     |             192 |
# |  339 | 2020-06-08 | Missing     |             193 |
# |  344 | 2020-06-09 | Missing     |             179 |
# |  349 | 2020-06-10 | Missing     |             187 |
# |  354 | 2020-06-11 | Missing     |             190 |
# |  359 | 2020-06-12 | Missing     |             197 |
# |  364 | 2020-06-13 | Missing     |             204 |
# |  369 | 2020-06-14 | Missing     |             206 |
# |  374 | 2020-06-15 | Missing     |             205 |
# |  379 | 2020-06-16 | Missing     |             201 |
# |  384 | 2020-06-17 | Missing     |             201 |
# |  389 | 2020-06-18 | Missing     |             205 |
# |  394 | 2020-06-19 | Missing     |             211 |
# |  399 | 2020-06-20 | Missing     |             195 |
# |  404 | 2020-06-21 | Missing     |             188 |
# |  409 | 2020-06-22 | Missing     |             201 |
# |  414 | 2020-06-23 | Missing     |             194 |
# |  419 | 2020-06-24 | Missing     |             196 |
# |  424 | 2020-06-25 | Missing     |             200 |
# |  429 | 2020-06-26 | Missing     |             214 |
# |  434 | 2020-06-27 | Missing     |            1058 |
# |  439 | 2020-06-28 | Missing     |             233 |
# |  444 | 2020-06-29 | Missing     |             231 |
# |  449 | 2020-06-30 | Missing     |             233 |
# |  454 | 2020-07-01 | Missing     |             246 |
# |  459 | 2020-07-02 | Missing     |             256 |
# |  464 | 2020-07-03 | Missing     |             272 |
# |  469 | 2020-07-04 | Missing     |             280 |
# |  474 | 2020-07-05 | Missing     |             308 |
# |  479 | 2020-07-06 | Missing     |             311 |
# |  484 | 2020-07-07 | Missing     |             325 |
# |  489 | 2020-07-08 | Missing     |             338 |
# |  494 | 2020-07-09 | Missing     |             356 |
# |  499 | 2020-07-10 | Missing     |             353 |
# |  504 | 2020-07-11 | Missing     |             370 |
# |  509 | 2020-07-12 | Missing     |             388 |
# |  514 | 2020-07-13 | Missing     |             456 |
# |  519 | 2020-07-14 | Missing     |             404 |
# |  524 | 2020-07-15 | Missing     |             404 |
# |  529 | 2020-07-16 | Missing     |             423 |
# |  534 | 2020-07-17 | Missing     |             472 |
# |  539 | 2020-07-18 | Missing     |             443 |
# |  544 | 2020-07-19 | Missing     |             457 |
# |  549 | 2020-07-20 | Missing     |             464 |
# |  554 | 2020-07-21 | Missing     |             473 |
# |  559 | 2020-07-22 | Missing     |             467 |
# |  564 | 2020-07-23 | Missing     |             491 |
# |  569 | 2020-07-24 | Missing     |             521 |
# |  574 | 2020-07-25 | Missing     |             531 |
# |  579 | 2020-07-26 | Missing     |             535 |
# |  584 | 2020-07-27 | Missing     |             535 |
# |  589 | 2020-07-28 | Missing     |             592 |
# |  594 | 2020-07-29 | Missing     |             589 |
# |  599 | 2020-07-30 | Missing     |             587 |
# |  604 | 2020-07-31 | Missing     |             619 |
# |  609 | 2020-08-01 | Missing     |             735 |
# |  614 | 2020-08-02 | Missing     |             708 |
# |  619 | 2020-08-03 | Missing     |             639 |
# |  624 | 2020-08-04 | Missing     |             656 |
# |  629 | 2020-08-05 | Missing     |             686 |
# |  634 | 2020-08-06 | Missing     |             717 |
# |  639 | 2020-08-07 | Missing     |             722 |
# |  644 | 2020-08-08 | Missing     |             748 |
# |  649 | 2020-08-09 | Missing     |             776 |
# |  654 | 2020-08-10 | Missing     |             776 |
# |  659 | 2020-08-11 | Missing     |             834 |
# |  664 | 2020-08-12 | Missing     |             838 |
# |  669 | 2020-08-13 | Missing     |             836 |
# |  674 | 2020-08-14 | Missing     |             846 |
# |  679 | 2020-08-15 | Missing     |             866 |
# |  684 | 2020-08-16 | Missing     |             862 |
# |  689 | 2020-08-17 | Missing     |             860 |
# |  694 | 2020-08-18 | Missing     |             862 |
# |  699 | 2020-08-19 | Missing     |             874 |
# |  704 | 2020-08-20 | Missing     |             894 |
# |  709 | 2020-08-21 | Missing     |             897 |
# |  714 | 2020-08-22 | Missing     |             909 |
# |  719 | 2020-08-23 | Missing     |             928 |
# |  724 | 2020-08-24 | Missing     |             929 |
# |  729 | 2020-08-25 | Missing     |             919 |
# |  734 | 2020-08-26 | Missing     |             909 |
# |  739 | 2020-08-27 | Missing     |             900 |
# |  744 | 2020-08-28 | Missing     |             901 |
# |  749 | 2020-08-29 | Missing     |             911 |
# |  754 | 2020-08-30 | Missing     |             908 |
# |  759 | 2020-08-31 | Missing     |             898 |
# |  764 | 2020-09-01 | Missing     |             889 |
# |  769 | 2020-09-02 | Missing     |             892 |
# |  774 | 2020-09-03 | Missing     |             902 |
# |  779 | 2020-09-04 | Missing     |             910 |
# |  784 | 2020-09-05 | Missing     |             908 |
# |  789 | 2020-09-06 | Missing     |             900 |
# |  794 | 2020-09-07 | Missing     |             903 |
# |  799 | 2020-09-08 | Missing     |             897 |
# |  804 | 2020-09-09 | Missing     |             905 |
# |  809 | 2020-09-10 | Missing     |             918 |
# |  814 | 2020-09-11 | Missing     |             936 |
# |  819 | 2020-09-12 | Missing     |             922 |
# |  824 | 2020-09-13 | Missing     |             921 |
# |  829 | 2020-09-14 | Missing     |             912 |
# |  834 | 2020-09-15 | Missing     |             914 |
# |  839 | 2020-09-16 | Missing     |             923 |
# |  844 | 2020-09-17 | Missing     |             922 |
# |  849 | 2020-09-18 | Missing     |             916 |
# |  854 | 2020-09-19 | Missing     |             910 |
# |  859 | 2020-09-20 | Missing     |             910 |
# |  864 | 2020-09-21 | Missing     |             911 |
# |  869 | 2020-09-22 | Missing     |             921 |
# |  874 | 2020-09-23 | Missing     |             922 |
# |  879 | 2020-09-24 | Missing     |             914 |
# |  884 | 2020-09-25 | Missing     |             889 |
# |  889 | 2020-09-26 | Missing     |             881 |
# |  894 | 2020-09-27 | Missing     |             883 |
# |  899 | 2020-09-28 | Missing     |             885 |
# |  904 | 2020-09-29 | Missing     |             889 |
# |  909 | 2020-09-30 | Missing     |             891 |
# |  914 | 2020-10-01 | Missing     |             890 |
# |  919 | 2020-10-02 | Missing     |             883 |
# |  924 | 2020-10-03 | Missing     |             884 |
# |  929 | 2020-10-04 | Missing     |             886 |
# |  934 | 2020-10-05 | Missing     |             884 |
# |  939 | 2020-10-06 | Missing     |             884 |
# |  944 | 2020-10-07 | Missing     |             887 |
# |  949 | 2020-10-08 | Missing     |             890 |
# |  954 | 2020-10-09 | Missing     |             884 |
# |  959 | 2020-10-10 | Missing     |             877 |
# |  964 | 2020-10-11 | Missing     |             882 |
# |  969 | 2020-10-12 | Missing     |             885 |
# |  974 | 2020-10-13 | Missing     |             895 |
# |  979 | 2020-10-14 | Missing     |             894 |
# |  984 | 2020-10-15 | Missing     |             891 |
# |  989 | 2020-10-16 | Missing     |             880 |
# |  994 | 2020-10-17 | Missing     |             861 |
# |  999 | 2020-10-18 | Missing     |             860 |
# | 1004 | 2020-10-19 | Missing     |             861 |
# | 1009 | 2020-10-20 | Missing     |             845 |
# | 1014 | 2020-10-21 | Missing     |             831 |
# | 1019 | 2020-10-22 | Missing     |             834 |
# | 1024 | 2020-10-23 | Missing     |             840 |
# | 1029 | 2020-10-24 | Missing     |             851 |
# | 1034 | 2020-10-25 | Missing     |             849 |
# | 1039 | 2020-10-26 | Missing     |             843 |
# | 1044 | 2020-10-27 | Missing     |             835 |
# | 1049 | 2020-10-28 | Missing     |             853 |
# | 1054 | 2020-10-29 | Missing     |             852 |
# | 1059 | 2020-10-30 | Missing     |             847 |
# | 1064 | 2020-10-31 | Missing     |             856 |
# | 1069 | 2020-11-01 | Missing     |             865 |
# | 1074 | 2020-11-02 | Missing     |             866 |
# | 1079 | 2020-11-03 | Missing     |             869 |
# | 1084 | 2020-11-04 | Missing     |             876 |
# | 1089 | 2020-11-05 | Missing     |             882 |
# | 1094 | 2020-11-06 | Missing     |             885 |
# | 1099 | 2020-11-07 | Missing     |             883 |
# | 1104 | 2020-11-08 | Missing     |             888 |
# | 1109 | 2020-11-09 | Missing     |             889 |
# | 1114 | 2020-11-10 | Missing     |             900 |
# | 1119 | 2020-11-11 | Missing     |             907 |
# | 1124 | 2020-11-12 | Missing     |             916 |
# | 1129 | 2020-11-13 | Missing     |             933 |
# | 1134 | 2020-11-14 | Missing     |             939 |
# | 1139 | 2020-11-15 | Missing     |             941 |
# | 1144 | 2020-11-16 | Missing     |             940 |
# | 1149 | 2020-11-17 | Missing     |             947 |
# | 1154 | 2020-11-18 | Missing     |             945 |
# | 1159 | 2020-11-19 | Missing     |             946 |
# | 1164 | 2020-11-20 | Missing     |             954 |
# | 1169 | 2020-11-21 | Missing     |             956 |
# | 1174 | 2020-11-22 | Missing     |             957 |
# | 1179 | 2020-11-23 | Missing     |             965 |
# | 1184 | 2020-11-24 | Missing     |             981 |
# | 1189 | 2020-11-25 | Missing     |             987 |
# | 1194 | 2020-11-26 | Missing     |            1001 |
# | 1199 | 2020-11-27 | Missing     |            1010 |
# | 1204 | 2020-11-28 | Missing     |            1015 |
# | 1209 | 2020-11-29 | Missing     |            1013 |
# | 1214 | 2020-11-30 | Missing     |            1019 |
# | 1219 | 2020-12-01 | Missing     |            1033 |
# | 1224 | 2020-12-02 | Missing     |            1047 |
# | 1229 | 2020-12-03 | Missing     |            1058 |
# | 1234 | 2020-12-04 | Missing     |            1079 |

# %%
grouped_covid_ages['age_group'].unique()
# Out:
# array(['0-17', '18-49', '50-64', '65 and Older', 'Missing'], dtype=object)

# %% [markdown]
# - Cell/Block 16 - how to go about deleting the missing data from the total cases since they're from two different dataframes; Thoughts: Extracting the rows with the missing age group, merging the two dataframes and then creating new column that subtracts the positive tests and the missing age group test results

# %%
# # Delete missing data from total
# # Create DF with just the missing age group and merge with
# # grouped_covid_cases on date
# missing = grouped_covid_ages[grouped_covid_ages['age_group']=='Missing']
# delete = pd.merge(missing, grouped_covid_cases)

# %%
# delete['totalconfirmed'] = delete['totalcountconfirmed'] - delete['totalpositive']
# delete['newconfirmedcount'] = delete['newcountconfirmed'] - delete['totalpositive']

# %%
# new = pd.merge(delete, grouped_covid_cases)
# new

# %%
# join the dataframes
covid_df = pd.merge(grouped_covid_ages, grouped_covid_cases)
covid_df
# Out:
#             date     age_group  totalpositive  totalcountconfirmed  \
# 0     2020-04-02          0-17            120              10701.0
# 1     2020-04-02         18-49           5302              10701.0
# 2     2020-04-02         50-64           2879              10701.0
# 3     2020-04-02  65 and Older           2342              10701.0
# 4     2020-04-02       Missing             58              10701.0
# ...          ...           ...            ...                  ...
# 1230  2020-12-04          0-17         147807            1311625.0
# 1231  2020-12-04         18-49         780365            1311625.0
# 1232  2020-12-04         50-64         246393            1311625.0
# 1233  2020-12-04  65 and Older         135981            1311625.0
# 1234  2020-12-04       Missing           1079            1311625.0
#
#       newcountconfirmed
# 0                  1510
# 1                  1510
# 2                  1510
# 3                  1510
# 4                  1510
# ...                 ...
# 1230              25068
# 1231              25068
# 1232              25068
# 1233              25068
# 1234              25068
#
# [1235 rows x 5 columns]

# %%
covid_df.head()
# Out:
#          date     age_group  totalpositive  totalcountconfirmed  \
# 0  2020-04-02          0-17            120              10701.0
# 1  2020-04-02         18-49           5302              10701.0
# 2  2020-04-02         50-64           2879              10701.0
# 3  2020-04-02  65 and Older           2342              10701.0
# 4  2020-04-02       Missing             58              10701.0
#
#    newcountconfirmed
# 0               1510
# 1               1510
# 2               1510
# 3               1510
# 4               1510

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1235 entries, 0 to 1234
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 1235 non-null   object
#  1   age_group            1235 non-null   object
#  2   totalpositive        1235 non-null   int64
#  3   totalcountconfirmed  1235 non-null   float64
#  4   newcountconfirmed    1235 non-null   int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 57.9+ KB

# %% [markdown]
# Where to go from here:
# - Pair with demographic age group size
# - Reverse engineer how many people in each age group tested +
# - Which age group contracted Covid/is at higher risk for contracting it?
# - Proportion of new cases vs population size

# %% [markdown]
# CA population (2019) data from https://censusreporter.org/data/table/?table=B01001&primary_geo_id=04000US06&geo_ids=04000US06,01000US

# %%
population = pd.read_csv('data/CA_population2019.csv')

# %%
# truncate dataframe
ca_population = population[2:20]
ca_population
# Out:
#                         Label California!!Total!!Estimate  \
# 2               Under 5 years                   2,377,839
# 3                5 to 9 years                   2,380,762
# 4              10 to 14 years                   2,629,510
# 5              15 to 19 years                   2,547,449
# 6              20 to 24 years                   2,638,791
# 7              25 to 29 years                   3,085,132
# 8              30 to 34 years                   2,950,920
# 9              35 to 39 years                   2,764,917
# 10             40 to 44 years                   2,533,994
# 11             45 to 49 years                   2,512,971
# 12             50 to 54 years                   2,461,846
# 13             55 to 59 years                   2,461,936
# 14             60 to 64 years                   2,331,158
# 15             65 to 69 years                   1,868,922
# 16             70 to 74 years                   1,522,934
# 17             75 to 79 years                   1,022,127
# 18             80 to 84 years                     703,715
# 19          85 years and over                     717,300
#
#    California!!Total!!Margin of Error California!!Percent!!Estimate  \
# 2                              ±3,612                          6.0%
# 3                             ±21,917                          6.0%
# 4                             ±20,779                          6.7%
# 5                              ±7,689                          6.4%
# 6                              ±6,800                          6.7%
# 7                              ±5,462                          7.8%
# 8                              ±5,779                          7.5%
# 9                             ±25,008                          7.0%
# 10                            ±24,316                          6.4%
# 11                             ±4,451                          6.4%
# 12                             ±4,731                          6.2%
# 13                            ±19,418                          6.2%
# 14                            ±19,848                          5.9%
# 15                            ±15,814                          4.7%
# 16                            ±15,948                          3.9%
# 17                            ±12,944                          2.6%
# 18                            ±12,963                          1.8%
# 19                            ±12,335                          1.8%
#
#    California!!Percent!!Margin of Error California!!Male!!Estimate  \
# 2                                  ±0.1                  1,215,418
# 3                                  ±0.1                  1,209,648
# 4                                  ±0.1                  1,350,641
# 5                                  ±0.1                  1,295,491
# 6                                  ±0.1                  1,360,772
# 7                                  ±0.1                  1,596,197
# 8                                  ±0.1                  1,520,141
# 9                                  ±0.1                  1,412,165
# 10                                 ±0.1                  1,270,506
# 11                                 ±0.1                  1,248,279
# 12                                 ±0.1                  1,228,836
# 13                                 ±0.1                  1,210,219
# 14                                 ±0.1                  1,122,638
# 15                                 ±0.1                    881,663
# 16                                 ±0.1                    695,971
# 17                                 ±0.1                    460,424
# 18                                 ±0.1                    294,548
# 19                                 ±0.1                    267,237
#
#    California!!Male!!Margin of Error California!!Percent Male!!Estimate  \
# 2                             ±3,802                               6.2%
# 3                            ±17,120                               6.2%
# 4                            ±16,386                               6.9%
# 5                             ±5,128                               6.6%
# 6                             ±5,142                               6.9%
# 7                             ±4,445                               8.1%
# 8                             ±4,080                               7.7%
# 9                            ±17,207                               7.2%
# 10                           ±16,867                               6.5%
# 11                            ±3,373                               6.4%
# 12                            ±3,628                               6.3%
# 13                           ±14,816                               6.2%
# 14                           ±14,872                               5.7%
# 15                           ±10,685                               4.5%
# 16                           ±10,913                               3.5%
# 17                            ±8,681                               2.3%
# 18                            ±7,899                               1.5%
# 19                            ±7,026                               1.4%
#
#    California!!Percent Male!!Margin of Error California!!Female!!Estimate  \
# 2                                       ±0.1                    1,162,421
# 3                                       ±0.1                    1,171,114
# 4                                       ±0.1                    1,278,869
# 5                                       ±0.1                    1,251,958
# 6                                       ±0.1                    1,278,019
# 7                                       ±0.1                    1,488,935
# 8                                       ±0.1                    1,430,779
# 9                                       ±0.1                    1,352,752
# 10                                      ±0.1                    1,263,488
# 11                                      ±0.1                    1,264,692
# 12                                      ±0.1                    1,233,010
# 13                                      ±0.1                    1,251,717
# 14                                      ±0.1                    1,208,520
# 15                                      ±0.1                      987,259
# 16                                      ±0.1                      826,963
# 17                                      ±0.1                      561,703
# 18                                      ±0.1                      409,167
# 19                                      ±0.1                      450,063
#
#    California!!Female!!Margin of Error California!!Percent Female!!Estimate  \
# 2                               ±3,349                                 5.8%
# 3                              ±14,583                                 5.9%
# 4                              ±14,246                                 6.4%
# 5                               ±5,829                                 6.3%
# 6                               ±4,272                                 6.4%
# 7                               ±3,731                                 7.5%
# 8                               ±3,848                                 7.2%
# 9                              ±13,954                                 6.8%
# 10                             ±14,212                                 6.4%
# 11                              ±3,126                                 6.4%
# 12                              ±2,636                                 6.2%
# 13                             ±13,893                                 6.3%
# 14                             ±14,121                                 6.1%
# 15                             ±11,153                                 5.0%
# 16                             ±10,951                                 4.2%
# 17                              ±8,808                                 2.8%
# 18                              ±8,236                                 2.1%
# 19                              ±9,248                                 2.3%
#
#    California!!Percent Female!!Margin of Error
# 2                                         ±0.1
# 3                                         ±0.1
# 4                                         ±0.1
# 5                                         ±0.1
# 6                                         ±0.1
# 7                                         ±0.1
# 8                                         ±0.1
# 9                                         ±0.1
# 10                                        ±0.1
# 11                                        ±0.1
# 12                                        ±0.1
# 13                                        ±0.1
# 14                                        ±0.1
# 15                                        ±0.1
# 16                                        ±0.1
# 17                                        ±0.1
# 18                                        ±0.1
# 19                                        ±0.1

# %%
# Rename Columns
columns = {'Label': 'Label', 
           'California!!Total!!Estimate': 'Total Estimate', 
           'California!!Total!!Margin of Error': 'Total Margin of Error',
           'California!!Percent!!Estimate': 'Percent Estimate', 
           'California!!Percent!!Margin of Error': 'Percent Margin of Error',
           'California!!Male!!Estimate': 'Male Estimate',
           'California!!Male!!Margin of Error': 'Male Margin of Error',
           'California!!Percent Male!!Estimate': 'Percent Male Estimate',
           'California!!Percent Male!!Margin of Error': 'Percent Male Margin of Error',
           'California!!Female!!Estimate': 'Female Estimate',
           'California!!Female!!Margin of Error': 'Female Margin of Error',
           'California!!Percent Female!!Estimate': 'Percent Female Estimate', 
           'California!!Percent Female!!Margin of Error': 'Percent Female Margin of Error'
          }
ca_population = ca_population.rename(columns = columns)

# %%
# Change Total Estimate, Male Estimate, and Female Estimate columnns as ints
change = ['Total Estimate', 'Male Estimate', 'Female Estimate']

# take out commas from the numbers and cast as int64
for col in change:
    ca_population[col] = ca_population[col].str.replace(',', '').astype('int64')

# %%
ca_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 2 to 19
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Label                           18 non-null     object
#  1   Total Estimate                  18 non-null     int64
#  2   Total Margin of Error           18 non-null     object
#  3   Percent Estimate                18 non-null     object
#  4   Percent Margin of Error         18 non-null     object
#  5   Male Estimate                   18 non-null     int64
#  6   Male Margin of Error            18 non-null     object
#  7   Percent Male Estimate           18 non-null     object
#  8   Percent Male Margin of Error    18 non-null     object
#  9   Female Estimate                 18 non-null     int64
#  10  Female Margin of Error          18 non-null     object
#  11  Percent Female Estimate         18 non-null     object
#  12  Percent Female Margin of Error  18 non-null     object
# dtypes: int64(3), object(10)
# memory usage: 2.0+ KB

# %%
ca_population
# Out:
#                         Label  Total Estimate Total Margin of Error  \
# 2               Under 5 years         2377839                ±3,612
# 3                5 to 9 years         2380762               ±21,917
# 4              10 to 14 years         2629510               ±20,779
# 5              15 to 19 years         2547449                ±7,689
# 6              20 to 24 years         2638791                ±6,800
# 7              25 to 29 years         3085132                ±5,462
# 8              30 to 34 years         2950920                ±5,779
# 9              35 to 39 years         2764917               ±25,008
# 10             40 to 44 years         2533994               ±24,316
# 11             45 to 49 years         2512971                ±4,451
# 12             50 to 54 years         2461846                ±4,731
# 13             55 to 59 years         2461936               ±19,418
# 14             60 to 64 years         2331158               ±19,848
# 15             65 to 69 years         1868922               ±15,814
# 16             70 to 74 years         1522934               ±15,948
# 17             75 to 79 years         1022127               ±12,944
# 18             80 to 84 years          703715               ±12,963
# 19          85 years and over          717300               ±12,335
#
#    Percent Estimate Percent Margin of Error  Male Estimate  \
# 2              6.0%                    ±0.1        1215418
# 3              6.0%                    ±0.1        1209648
# 4              6.7%                    ±0.1        1350641
# 5              6.4%                    ±0.1        1295491
# 6              6.7%                    ±0.1        1360772
# 7              7.8%                    ±0.1        1596197
# 8              7.5%                    ±0.1        1520141
# 9              7.0%                    ±0.1        1412165
# 10             6.4%                    ±0.1        1270506
# 11             6.4%                    ±0.1        1248279
# 12             6.2%                    ±0.1        1228836
# 13             6.2%                    ±0.1        1210219
# 14             5.9%                    ±0.1        1122638
# 15             4.7%                    ±0.1         881663
# 16             3.9%                    ±0.1         695971
# 17             2.6%                    ±0.1         460424
# 18             1.8%                    ±0.1         294548
# 19             1.8%                    ±0.1         267237
#
#    Male Margin of Error Percent Male Estimate Percent Male Margin of Error  \
# 2                ±3,802                  6.2%                         ±0.1
# 3               ±17,120                  6.2%                         ±0.1
# 4               ±16,386                  6.9%                         ±0.1
# 5                ±5,128                  6.6%                         ±0.1
# 6                ±5,142                  6.9%                         ±0.1
# 7                ±4,445                  8.1%                         ±0.1
# 8                ±4,080                  7.7%                         ±0.1
# 9               ±17,207                  7.2%                         ±0.1
# 10              ±16,867                  6.5%                         ±0.1
# 11               ±3,373                  6.4%                         ±0.1
# 12               ±3,628                  6.3%                         ±0.1
# 13              ±14,816                  6.2%                         ±0.1
# 14              ±14,872                  5.7%                         ±0.1
# 15              ±10,685                  4.5%                         ±0.1
# 16              ±10,913                  3.5%                         ±0.1
# 17               ±8,681                  2.3%                         ±0.1
# 18               ±7,899                  1.5%                         ±0.1
# 19               ±7,026                  1.4%                         ±0.1
#
#     Female Estimate Female Margin of Error Percent Female Estimate  \
# 2           1162421                 ±3,349                    5.8%
# 3           1171114                ±14,583                    5.9%
# 4           1278869                ±14,246                    6.4%
# 5           1251958                 ±5,829                    6.3%
# 6           1278019                 ±4,272                    6.4%
# 7           1488935                 ±3,731                    7.5%
# 8           1430779                 ±3,848                    7.2%
# 9           1352752                ±13,954                    6.8%
# 10          1263488                ±14,212                    6.4%
# 11          1264692                 ±3,126                    6.4%
# 12          1233010                 ±2,636                    6.2%
# 13          1251717                ±13,893                    6.3%
# 14          1208520                ±14,121                    6.1%
# 15           987259                ±11,153                    5.0%
# 16           826963                ±10,951                    4.2%
# 17           561703                 ±8,808                    2.8%
# 18           409167                 ±8,236                    2.1%
# 19           450063                 ±9,248                    2.3%
#
#    Percent Female Margin of Error
# 2                            ±0.1
# 3                            ±0.1
# 4                            ±0.1
# 5                            ±0.1
# 6                            ±0.1
# 7                            ±0.1
# 8                            ±0.1
# 9                            ±0.1
# 10                           ±0.1
# 11                           ±0.1
# 12                           ±0.1
# 13                           ±0.1
# 14                           ±0.1
# 15                           ±0.1
# 16                           ±0.1
# 17                           ±0.1
# 18                           ±0.1
# 19                           ±0.1

# %%
# Merge the age groups to reflect the age groups in Covid data
# Age groups for Covid: 0-17, 18-49, 50-64, 65 and Older, Unknown, Missing
until_19 = ca_population[0:4]['Total Estimate'].sum()
from_20_49 = ca_population[4:10]['Total Estimate'].sum()
from_50_64 = ca_population[10:13]['Total Estimate'].sum()
older_65 = ca_population[13:]['Total Estimate'].sum()
print(until_19, from_20_49, from_50_64, older_65)
# Out:
# 9935560 16486725 7254940 5834998

# %% [markdown]
# Under 17 age group data frfom: https://www.kidsdata.org/topic/34/child-population-age-gender/table#fmt=141&loc=2&tf=110&ch=1433,926,927,1434,1435,372,78,77,79&sortColumnId=0&sortType=asc

# %%
# Subtract ages 18-19 from the until_19 age group
# read in table of California age group of people 0-17
children_df = pd.read_csv('data/CA_Under17Population.csv')
children_df
# Out:
#     FIPSCode LocationType    Location             AgeGroup  Gender  TimeFrame  \
# 0          6        State  California             Ages 0_2  Female       2020
# 1          6        State  California             Ages 0_2    Male       2020
# 2          6        State  California             Ages 0_2   Total       2020
# 3          6        State  California           Ages 11_13  Female       2020
# 4          6        State  California           Ages 11_13    Male       2020
# 5          6        State  California           Ages 11_13   Total       2020
# 6          6        State  California           Ages 14_17  Female       2020
# 7          6        State  California           Ages 14_17    Male       2020
# 8          6        State  California           Ages 14_17   Total       2020
# 9          6        State  California             Ages 3_5  Female       2020
# 10         6        State  California             Ages 3_5    Male       2020
# 11         6        State  California             Ages 3_5   Total       2020
# 12         6        State  California            Ages 6_10  Female       2020
# 13         6        State  California            Ages 6_10    Male       2020
# 14         6        State  California            Ages 6_10   Total       2020
# 15         6        State  California  Total for Ages 0_17  Female       2020
# 16         6        State  California  Total for Ages 0_17    Male       2020
# 17         6        State  California  Total for Ages 0_17   Total       2020
#
#    DataFormat       Data
# 0      Number    666,477
# 1      Number    697,215
# 2      Number  1,363,692
# 3      Number    770,448
# 4      Number    800,496
# 5      Number  1,570,944
# 6      Number  1,017,713
# 7      Number  1,055,961
# 8      Number  2,073,674
# 9      Number    715,327
# 10     Number    749,841
# 11     Number  1,465,168
# 12     Number  1,249,146
# 13     Number  1,303,428
# 14     Number  2,552,574
# 15     Number  4,419,111
# 16     Number  4,606,941
# 17     Number  9,026,052

# %%
# Extract necessary row and delete all columns that aren't the total
children = children_df.iloc[-1][-1]
type(children) # str
# Convert to int64
chidren_no_commas = children.replace(',', '')
under_17 = int(chidren_no_commas)

# %%
# Subtract under_17 from until_19
ages18_19 = until_19 - under_17
# add ages18_19 to from_20_49
from_18_49 = sum([ages18_19, from_20_49])
print(f'until 19: {until_19}\n\
0-17: {under_17}\n\
18-19: {ages18_19}\n\
20-49: {from_20_49}\n\
18-49: {from_18_49}\n\
50-64: {from_50_64}\n\
65 and older: {older_65}')
# Out:
# until 19: 9935560
# 0-17: 9026052
# 18-19: 909508
# 20-49: 16486725
# 18-49: 17396233
# 50-64: 7254940
# 65 and older: 5834998

# %%
# Create DataFrame of the age group populations
# ['0-17', '18-49', '50-64', '65 and Older', 'Unknown', '65+', 'Missing']
d = {'0-17': under_17, '18-49': from_18_49,\
        '50-64': from_50_64, '65 and Older': older_65}
ages = pd.Series(data=d)
ages
# Out:
# 0-17             9026052
# 18-49           17396233
# 50-64            7254940
# 65 and Older     5834998
# dtype: int64

# %%
# Create proportions of age_group positive rate vs age_group population
pop_proportions = []
for pos, age in zip(covid_df['totalpositive'], covid_df['age_group']):
    if age == '0-17':
        pop_proportions.append(round(pos/ages[0], 5))
    elif age == '18-49':
        pop_proportions.append(round(pos/ages[1], 5))
    elif age == '50-64':
        pop_proportions.append(round(pos/ages[2], 5))
    elif age == '65 and Older':
        pop_proportions.append(round(pos/ages[3], 5))
    else:
        pop_proportions.append(0)

# %%
# Create agegroup_proportion column
covid_df['agegroup_pop_proportion'] = pop_proportions
# Out:
# /Users/belindanguyen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
covid_df.head(10)
# Out:
#          date     age_group  totalpositive  totalcountconfirmed  \
# 0  2020-04-02          0-17            120              10701.0
# 1  2020-04-02         18-49           5302              10701.0
# 2  2020-04-02         50-64           2879              10701.0
# 3  2020-04-02  65 and Older           2342              10701.0
# 4  2020-04-02       Missing             58              10701.0
# 5  2020-04-03          0-17            137              12026.0
# 6  2020-04-03         18-49           5917              12026.0
# 7  2020-04-03         50-64           3253              12026.0
# 8  2020-04-03  65 and Older           2660              12026.0
# 9  2020-04-03       Missing             59              12026.0
#
#    newcountconfirmed  agegroup_proportion
# 0               1510              0.00001
# 1               1510              0.00030
# 2               1510              0.00040
# 3               1510              0.00040
# 4               1510              0.00000
# 5               1325              0.00002
# 6               1325              0.00034
# 7               1325              0.00045
# 8               1325              0.00046
# 9               1325              0.00000

# %%
# Create new column for new covid cases added per age group per day
newcount_age = []
# Estimate new cases per age group per day for first day
# by taking proportion of cases in group/total cases * new cases
# Sums to 1509 instead of 1510
for i in range(0,5):
    newcount_age.append(int(round(covid_df['totalpositive'].iloc[i]/covid_df['totalcountconfirmed'].iloc[i]*covid_df['newcountconfirmed'].iloc[i])))

# Find the rest of the new caases added per day per age group
for i in range(5, len(covid_df['age_group'])):
    newcount_age.append(covid_df['totalpositive'].iloc[i]-covid_df['totalpositive'].iloc[i-5])
newcount_age
# Note: The negative values represent the missing age group having going down in count
# Perhaps the age group for people in missing was found
# Out:
# [17,
#  748,
#  406,
#  330,
#  8,
#  17,
#  615,
#  374,
#  318,
#  1,
#  23,
#  693,
#  400,
#  306,
#  -10,
#  13,
#  489,
#  231,
#  163,
#  2,
#  24,
#  654,
#  460,
#  387,
#  4,
#  25,
#  536,
#  295,
#  235,
#  1,
#  30,
#  650,
#  364,
#  305,
#  3,
#  17,
#  530,
#  344,
#  279,
#  -7,
#  34,
#  600,
#  286,
#  226,
#  -3,
#  27,
#  530,
#  308,
#  309,
#  5,
#  7,
#  239,
#  138,
#  166,
#  4,
#  25,
#  408,
#  269,
#  284,
#  4,
#  23,
#  475,
#  296,
#  285,
#  7,
#  47,
#  758,
#  497,
#  446,
#  10,
#  40,
#  665,
#  347,
#  309,
#  -15,
#  35,
#  654,
#  374,
#  369,
#  3,
#  43,
#  610,
#  370,
#  342,
#  5,
#  23,
#  282,
#  153,
#  196,
#  -9,
#  110,
#  1211,
#  576,
#  383,
#  3,
#  85,
#  1108,
#  556,
#  385,
#  1,
#  87,
#  995,
#  508,
#  366,
#  17,
#  81,
#  950,
#  426,
#  431,
#  -3,
#  75,
#  943,
#  434,
#  424,
#  7,
#  28,
#  482,
#  254,
#  256,
#  7,
#  46,
#  649,
#  303,
#  312,
#  -10,
#  105,
#  860,
#  339,
#  262,
#  1,
#  73,
#  708,
#  372,
#  327,
#  -11,
#  135,
#  1240,
#  552,
#  493,
#  -3,
#  51,
#  777,
#  339,
#  350,
#  8,
#  117,
#  935,
#  410,
#  291,
#  2,
#  74,
#  708,
#  319,
#  313,
#  5,
#  75,
#  700,
#  305,
#  238,
#  3,
#  58,
#  600,
#  288,
#  327,
#  2,
#  164,
#  1412,
#  608,
#  417,
#  2,
#  118,
#  934,
#  401,
#  352,
#  -6,
#  126,
#  958,
#  418,
#  386,
#  10,
#  79,
#  1144,
#  457,
#  368,
#  1,
#  113,
#  1186,
#  479,
#  342,
#  -1,
#  71,
#  615,
#  273,
#  307,
#  -7,
#  105,
#  768,
#  320,
#  248,
#  2,
#  123,
#  994,
#  379,
#  253,
#  10,
#  127,
#  1035,
#  453,
#  400,
#  8,
#  152,
#  1035,
#  356,
#  227,
#  2,
#  113,
#  974,
#  398,
#  376,
#  -4,
#  161,
#  1040,
#  457,
#  388,
#  0,
#  130,
#  888,
#  338,
#  238,
#  -3,
#  91,
#  782,
#  300,
#  193,
#  -1,
#  211,
#  1270,
#  465,
#  312,
#  4,
#  198,
#  1158,
#  499,
#  281,
#  4,
#  194,
#  1203,
#  494,
#  351,
#  5,
#  224,
#  1179,
#  477,
#  300,
#  7,
#  189,
#  1200,
#  423,
#  260,
#  7,
#  171,
#  1033,
#  393,
#  246,
#  5,
#  239,
#  1279,
#  431,
#  228,
#  -2,
#  250,
#  1338,
#  448,
#  197,
#  14,
#  249,
#  1574,
#  521,
#  367,
#  6,
#  171,
#  1240,
#  463,
#  311,
#  4,
#  319,
#  1757,
#  606,
#  300,
#  10,
#  393,
#  2186,
#  741,
#  382,
#  3,
#  234,
#  1406,
#  441,
#  337,
#  5,
#  218,
#  1349,
#  475,
#  262,
#  0,
#  219,
#  1403,
#  454,
#  300,
#  1,
#  194,
#  1256,
#  428,
#  241,
#  1,
#  289,
#  1762,
#  634,
#  407,
#  2,
#  270,
#  1841,
#  637,
#  363,
#  4,
#  269,
#  1657,
#  523,
#  339,
#  8,
#  301,
#  1503,
#  469,
#  235,
#  -1,
#  261,
#  1318,
#  375,
#  215,
#  1,
#  291,
#  1596,
#  514,
#  315,
#  -14,
#  336,
#  1793,
#  616,
#  337,
#  8,
#  325,
#  1598,
#  539,
#  237,
#  3,
#  358,
#  2221,
#  714,
#  360,
#  7,
#  365,
#  1907,
#  574,
#  359,
#  7,
#  267,
#  1595,
#  514,
#  219,
#  2,
#  251,
#  1311,
#  419,
#  128,
#  -1,
#  362,
#  2071,
#  632,
#  394,
#  -4,
#  518,
#  2471,
#  687,
#  408,
#  0,
#  481,
#  2482,
#  876,
#  474,
#  4,
#  378,
#  2425,
#  728,
#  356,
#  6,
#  456,
#  2810,
#  833,
#  432,
#  -16,
#  449,
#  2756,
#  749,
#  283,
#  -7,
#  521,
#  3205,
#  872,
#  408,
#  13,
#  657,
#  4579,
#  1256,
#  664,
#  -7,
#  444,
#  3436,
#  947,
#  520,
#  2,
#  481,
#  3058,
#  851,
#  496,
#  4,
#  644,
#  3842,
#  1009,
#  463,
#  14,
#  453,
#  2534,
#  653,
#  326,
#  844,
#  611,
#  3910,
#  1051,
#  560,
#  -825,
#  582,
#  4249,
#  1052,
#  486,
#  -2,
#  933,
#  6376,
#  1663,
#  766,
#  2,
#  656,
#  4882,
#  1317,
#  670,
#  13,
#  760,
#  5261,
#  1379,
#  630,
#  10,
#  522,
#  4252,
#  1110,
#  610,
#  16,
#  609,
#  3441,
#  914,
#  438,
#  8,
#  1113,
#  7473,
#  1967,
#  948,
#  28,
#  529,
#  3947,
#  1095,
#  516,
#  3,
#  1099,
#  7541,
#  2086,
#  954,
#  14,
#  596,
#  4464,
#  1283,
#  675,
#  13,
#  604,
#  5008,
#  1408,
#  760,
#  18,
#  729,
#  5212,
#  1416,
#  693,
#  -3,
#  763,
#  5371,
#  1572,
#  737,
#  17,
#  763,
#  5442,
#  1438,
#  697,
#  18,
#  693,
#  4685,
#  1293,
#  607,
#  68,
#  1048,
#  7137,
#  2066,
#  927,
#  -52,
#  789,
#  5509,
#  1505,
#  741,
#  0,
#  1073,
#  6402,
#  1690,
#  802,
#  19,
#  935,
#  5794,
#  1674,
#  747,
#  49,
#  960,
#  5892,
#  1637,
#  869,
#  -29,
#  717,
#  4342,
#  1180,
#  593,
#  14,
#  987,
#  5893,
#  1608,
#  736,
#  7,
#  1345,
#  8006,
#  2269,
#  1178,
#  9,
#  1373,
#  7441,
#  2161,
#  1071,
#  -6,
#  966,
#  5927,
#  1897,
#  904,
#  24,
#  1095,
#  6151,
#  1920,
#  870,
#  30,
#  1011,
#  5106,
#  1460,
#  672,
#  10,
#  741,
#  4258,
#  1306,
#  582,
#  4,
#  688,
#  3713,
#  1069,
#  530,
#  0,
#  861,
#  5405,
#  1596,
#  836,
#  57,
#  1183,
#  6308,
#  1808,
#  901,
#  -3,
#  913,
#  5014,
#  1457,
#  704,
#  -2,
#  727,
#  4004,
#  1162,
#  617,
#  32,
#  1036,
#  5375,
#  1659,
#  846,
#  116,
#  730,
#  3433,
#  1023,
#  580,
#  -27,
#  634,
#  2691,
#  809,
#  461,
#  -69,
#  604,
#  3049,
#  1025,
#  600,
#  17,
#  634,
#  2987,
#  996,
#  611,
#  30,
#  1035,
#  5009,
#  1537,
#  824,
#  31,
#  939,
#  4399,
#  1356,
#  672,
#  5,
#  972,
#  4937,
#  1563,
#  875,
#  26,
#  1032,
#  4616,
#  1440,
#  635,
#  28,
#  1642,
#  7402,
#  2414,
#  1042,
#  0,
#  1498,
#  6881,
#  2097,
#  1111,
#  58,
#  954,
#  4158,
#  1288,
#  681,
#  4,
#  916,
#  4668,
#  1534,
#  818,
#  -2,
#  1536,
#  7428,
#  2353,
#  1287,
#  10,
#  948,
#  4628,
#  1512,
#  765,
#  20,
#  908,
#  3786,
#  1131,
#  648,
#  -4,
#  695,
#  2737,
#  811,
#  395,
#  -2,
#  885,
#  3601,
#  1081,
#  595,
#  2,
#  791,
#  3510,
#  1033,
#  574,
#  12,
#  664,
#  3287,
#  1037,
#  577,
#  20,
#  787,
#  3785,
#  1250,
#  731,
#  3,
#  844,
#  3954,
#  1200,
#  767,
#  12,
#  624,
#  2900,
#  957,
#  446,
#  19,
#  634,
#  2539,
#  849,
#  457,
#  1,
#  701,
#  3601,
#  1082,
#  630,
#  -10,
#  568,
#  2568,
#  803,
#  501,
#  -10,
#  638,
#  3096,
#  969,
#  635,
#  -9,
#  595,
#  2851,
#  993,
#  541,
#  1,
#  713,
#  3616,
#  1112,
#  619,
#  10,
#  547,
#  2460,
#  727,
#  445,
#  -3,
#  552,
#  2159,
#  642,
#  369,
#  -10,
#  495,
#  2669,
#  687,
#  413,
#  -9,
#  551,
#  2956,
#  935,
#  680,
#  3,
#  508,
#  3012,
#  960,
#  616,
#  10,
#  585,
#  3024,
#  884,
#  455,
#  8,
#  575,
#  2999,
#  855,
#  478,
#  -2,
#  396,
#  1826,
#  571,
#  306,
#  -8,
#  312,
#  1610,
#  496,
#  255,
#  3,
#  184,
#  960,
#  303,
#  175,
#  -6,
#  387,
#  1994,
#  622,
#  327,
#  8,
#  367,
#  1976,
#  590,
#  380,
#  13,
#  457,
#  2465,
#  720,
#  447,
#  18,
#  594,
#  2793,
#  829,
#  423,
#  -14,
#  373,
#  1677,
#  526,
#  280,
#  -1,
#  299,
#  1362,
#  410,
#  173,
#  -9,
#  333,
#  1746,
#  553,
#  316,
#  2,
#  314,
#  1984,
#  605,
#  326,
#  9,
#  440,
#  2100,
#  718,
#  373,
#  -1,
#  556,
#  2498,
#  823,
#  433,
#  -6,
#  567,
#  2492,
#  787,
#  425,
#  -6,
#  439,
#  1976,
#  575,
#  304,
#  0,
#  360,
#  1463,
#  553,
#  253,
#  1,
#  309,
#  1868,
#  583,
#  376,
#  10,
#  368,
#  1858,
#  596,
#  347,
#  1,
#  397,
#  2041,
#  622,
#  348,
#  -8,
#  542,
#  2502,
#  751,
#  427,
#  -25,
#  540,
#  2419,
#  778,
#  342,
#  -8,
#  383,
#  1741,
#  552,
#  277,
#  2,
#  288,
#  1254,
#  397,
#  221,
#  2,
#  369,
#  1875,
#  574,
#  378,
#  4,
#  404,
#  1789,
#  554,
#  313,
#  2,
#  403,
#  2067,
#  715,
#  406,
#  -1,
#  375,
#  1296,
#  320,
#  175,
#  -7,
#  502,
#  2534,
#  779,
#  477,
#  1,
#  389,
#  1782,
#  609,
#  273,
#  2,
#  233,
#  973,
#  305,
#  168,
#  -2,
#  350,
#  1581,
#  533,
#  300,
#  0,
#  481,
#  2040,
#  701,
#  350,
#  3,
#  456,
#  2239,
#  687,
#  421,
#  3,
#  546,
#  2443,
#  795,
#  392,
#  -6,
#  488,
#  2291,
#  709,
#  322,
#  -7,
#  447,
#  2019,
#  656,
#  322,
#  5,
#  360,
#  1369,
#  430,
#  216,
#  3,
#  345,
#  1541,
#  506,
#  264,
#  10,
#  416,
#  1978,
#  628,
#  308,
#  -1,
#  386,
#  1767,
#  587,
#  338,
#  -3,
#  406,
#  1721,
#  533,
#  330,
#  -11,
#  420,
#  1646,
#  516,
#  299,
#  -19,
#  464,
#  2093,
#  601,
#  317,
#  -1,
#  ...]

# %%
# add new column
covid_df['newconfirmed_age'] = newcount_age
# Out:
#           date     age_group  totalpositive  totalcountconfirmed  \
# 0   2020-04-02          0-17            120              10701.0
# 1   2020-04-02         18-49           5302              10701.0
# 2   2020-04-02         50-64           2879              10701.0
# 3   2020-04-02  65 and Older           2342              10701.0
# 4   2020-04-02       Missing             58              10701.0
# 5   2020-04-03          0-17            137              12026.0
# 6   2020-04-03         18-49           5917              12026.0
# 7   2020-04-03         50-64           3253              12026.0
# 8   2020-04-03  65 and Older           2660              12026.0
# 9   2020-04-03       Missing             59              12026.0
# 10  2020-04-04          0-17            160              13438.0
# 11  2020-04-04         18-49           6610              13438.0
# 12  2020-04-04         50-64           3653              13438.0
# 13  2020-04-04  65 and Older           2966              13438.0
# 14  2020-04-04       Missing             49              13438.0
# 15  2020-04-05          0-17            173              14336.0
# 16  2020-04-05         18-49           7099              14336.0
# 17  2020-04-05         50-64           3884              14336.0
# 18  2020-04-05  65 and Older           3129              14336.0
# 19  2020-04-05       Missing             51              14336.0
# 20  2020-04-06          0-17            197              15865.0
# 21  2020-04-06         18-49           7753              15865.0
# 22  2020-04-06         50-64           4344              15865.0
# 23  2020-04-06  65 and Older           3516              15865.0
# 24  2020-04-06       Missing             55              15865.0
# 25  2020-04-07          0-17            222              16957.0
# 26  2020-04-07         18-49           8289              16957.0
# 27  2020-04-07         50-64           4639              16957.0
# 28  2020-04-07  65 and Older           3751              16957.0
# 29  2020-04-07       Missing             56              16957.0
#
#     newcountconfirmed  agegroup_proportion  newconfirmed_age
# 0                1510              0.00001                17
# 1                1510              0.00030               748
# 2                1510              0.00040               406
# 3                1510              0.00040               330
# 4                1510              0.00000                 8
# 5                1325              0.00002                17
# 6                1325              0.00034               615
# 7                1325              0.00045               374
# 8                1325              0.00046               318
# 9                1325              0.00000                 1
# 10               1412              0.00002                23
# 11               1412              0.00038               693
# 12               1412              0.00050               400
# 13               1412              0.00051               306
# 14               1412              0.00000               -10
# 15                898              0.00002                13
# 16                898              0.00041               489
# 17                898              0.00054               231
# 18                898              0.00054               163
# 19                898              0.00000                 2
# 20               1529              0.00002                24
# 21               1529              0.00045               654
# 22               1529              0.00060               460
# 23               1529              0.00060               387
# 24               1529              0.00000                 4
# 25               1092              0.00002                25
# 26               1092              0.00048               536
# 27               1092              0.00064               295
# 28               1092              0.00064               235
# 29               1092              0.00000                 1

# %%
age_positive_proportion = []
for pos, total in zip(covid_df['totalpositive'], covid_df['totalcountconfirmed']):
    age_positive_proportion.append(round(pos/total, 5))

# %%
covid_df['age_positive_proportion'] = age_positive_proportion
# Out:
# /Users/belindanguyen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Rearrange columns
covid_df = covid_df[['date', 'age_group', 'totalpositive', 'totalcountconfirmed',
       'newcountconfirmed', 'newconfirmed_age', 'age_positive_proportion', 'agegroup_pop_proportion',
       'newconfirmed_proportion']]

# %%
# Check out head and tail of data
covid_df.head(30)

# %%
covid_df.tail(30)
# Out:
#             date     age_group  totalpositive  totalcountconfirmed  \
# 1205  2020-11-29          0-17         135365            1212968.0
# 1206  2020-11-29         18-49         722382            1212968.0
# 1207  2020-11-29         50-64         227953            1212968.0
# 1208  2020-11-29  65 and Older         126255            1212968.0
# 1209  2020-11-29       Missing           1013            1212968.0
# 1210  2020-11-30          0-17         136904            1225189.0
# 1211  2020-11-30         18-49         729630            1225189.0
# 1212  2020-11-30         50-64         230204            1225189.0
# 1213  2020-11-30  65 and Older         127432            1225189.0
# 1214  2020-11-30       Missing           1019            1225189.0
# 1215  2020-12-01          0-17         139427            1245948.0
# 1216  2020-12-01         18-49         741663            1245948.0
# 1217  2020-12-01         50-64         234277            1245948.0
# 1218  2020-12-01  65 and Older         129548            1245948.0
# 1219  2020-12-01       Missing           1033            1245948.0
# 1220  2020-12-02          0-17         141712            1264539.0
# 1221  2020-12-02         18-49         752442            1264539.0
# 1222  2020-12-02         50-64         237843            1264539.0
# 1223  2020-12-02  65 and Older         131495            1264539.0
# 1224  2020-12-02       Missing           1047            1264539.0
# 1225  2020-12-03          0-17         144555            1286557.0
# 1226  2020-12-03         18-49         765403            1286557.0
# 1227  2020-12-03         50-64         241906            1286557.0
# 1228  2020-12-03  65 and Older         133635            1286557.0
# 1229  2020-12-03       Missing           1058            1286557.0
# 1230  2020-12-04          0-17         147807            1311625.0
# 1231  2020-12-04         18-49         780365            1311625.0
# 1232  2020-12-04         50-64         246393            1311625.0
# 1233  2020-12-04  65 and Older         135981            1311625.0
# 1234  2020-12-04       Missing           1079            1311625.0
#
#       newcountconfirmed  agegroup_proportion  newconfirmed_age
# 1205              14034              0.01500              1779
# 1206              14034              0.04153              8000
# 1207              14034              0.03142              2746
# 1208              14034              0.02164              1511
# 1209              14034              0.00000                -2
# 1210              12221              0.01517              1539
# 1211              12221              0.04194              7248
# 1212              12221              0.03173              2251
# 1213              12221              0.02184              1177
# 1214              12221              0.00000                 6
# 1215              20759              0.01545              2523
# 1216              20759              0.04263             12033
# 1217              20759              0.03229              4073
# 1218              20759              0.02220              2116
# 1219              20759              0.00000                14
# 1220              18591              0.01570              2285
# 1221              18591              0.04325             10779
# 1222              18591              0.03278              3566
# 1223              18591              0.02254              1947
# 1224              18591              0.00000                14
# 1225              22018              0.01602              2843
# 1226              22018              0.04400             12961
# 1227              22018              0.03334              4063
# 1228              22018              0.02290              2140
# 1229              22018              0.00000                11
# 1230              25068              0.01638              3252
# 1231              25068              0.04486             14962
# 1232              25068              0.03396              4487
# 1233              25068              0.02330              2346
# 1234              25068              0.00000                21

# %%
# Create Proportion column of cases added per day per age group
newconfirmed_proportion = []
for i in range(len(covid_df['age_group'])):
    newconfirmed_proportion.append(covid_df['newconfirmed_age'].iloc[i]/covid_df['newcountconfirmed'].iloc[i])
covid_df['newconfirmed_proportion'] = newconfirmed_proportion

# %%
covid_df.head(30)
# Out:
#           date     age_group  totalpositive  totalcountconfirmed  \
# 0   2020-04-02          0-17            120              10701.0
# 1   2020-04-02         18-49           5302              10701.0
# 2   2020-04-02         50-64           2879              10701.0
# 3   2020-04-02  65 and Older           2342              10701.0
# 4   2020-04-02       Missing             58              10701.0
# 5   2020-04-03          0-17            137              12026.0
# 6   2020-04-03         18-49           5917              12026.0
# 7   2020-04-03         50-64           3253              12026.0
# 8   2020-04-03  65 and Older           2660              12026.0
# 9   2020-04-03       Missing             59              12026.0
# 10  2020-04-04          0-17            160              13438.0
# 11  2020-04-04         18-49           6610              13438.0
# 12  2020-04-04         50-64           3653              13438.0
# 13  2020-04-04  65 and Older           2966              13438.0
# 14  2020-04-04       Missing             49              13438.0
# 15  2020-04-05          0-17            173              14336.0
# 16  2020-04-05         18-49           7099              14336.0
# 17  2020-04-05         50-64           3884              14336.0
# 18  2020-04-05  65 and Older           3129              14336.0
# 19  2020-04-05       Missing             51              14336.0
# 20  2020-04-06          0-17            197              15865.0
# 21  2020-04-06         18-49           7753              15865.0
# 22  2020-04-06         50-64           4344              15865.0
# 23  2020-04-06  65 and Older           3516              15865.0
# 24  2020-04-06       Missing             55              15865.0
# 25  2020-04-07          0-17            222              16957.0
# 26  2020-04-07         18-49           8289              16957.0
# 27  2020-04-07         50-64           4639              16957.0
# 28  2020-04-07  65 and Older           3751              16957.0
# 29  2020-04-07       Missing             56              16957.0
#
#     newcountconfirmed  agegroup_proportion  newconfirmed_age  \
# 0                1510              0.00001                17
# 1                1510              0.00030               748
# 2                1510              0.00040               406
# 3                1510              0.00040               330
# 4                1510              0.00000                 8
# 5                1325              0.00002                17
# 6                1325              0.00034               615
# 7                1325              0.00045               374
# 8                1325              0.00046               318
# 9                1325              0.00000                 1
# 10               1412              0.00002                23
# 11               1412              0.00038               693
# 12               1412              0.00050               400
# 13               1412              0.00051               306
# 14               1412              0.00000               -10
# 15                898              0.00002                13
# 16                898              0.00041               489
# 17                898              0.00054               231
# 18                898              0.00054               163
# 19                898              0.00000                 2
# 20               1529              0.00002                24
# 21               1529              0.00045               654
# 22               1529              0.00060               460
# 23               1529              0.00060               387
# 24               1529              0.00000                 4
# 25               1092              0.00002                25
# 26               1092              0.00048               536
# 27               1092              0.00064               295
# 28               1092              0.00064               235
# 29               1092              0.00000                 1
#
#     newconfirmed_proportion
# 0                  0.011258
# 1                  0.495364
# 2                  0.268874
# 3                  0.218543
# 4                  0.005298
# 5                  0.012830
# 6                  0.464151
# 7                  0.282264
# 8                  0.240000
# 9                  0.000755
# 10                 0.016289
# 11                 0.490793
# 12                 0.283286
# 13                 0.216714
# 14                -0.007082
# 15                 0.014477
# 16                 0.544543
# 17                 0.257238
# 18                 0.181514
# 19                 0.002227
# 20                 0.015697
# 21                 0.427731
# 22                 0.300850
# 23                 0.253107
# 24                 0.002616
# 25                 0.022894
# 26                 0.490842
# 27                 0.270147
# 28                 0.215201
# 29                 0.000916

# %%
covid_df.tail(5)
# Out:
#             date     age_group  totalpositive  totalcountconfirmed  \
# 1230  2020-12-04          0-17         147807            1311625.0
# 1231  2020-12-04         18-49         780365            1311625.0
# 1232  2020-12-04         50-64         246393            1311625.0
# 1233  2020-12-04  65 and Older         135981            1311625.0
# 1234  2020-12-04       Missing           1079            1311625.0
#
#       newcountconfirmed  agegroup_proportion  newconfirmed_age  \
# 1230              25068              0.01638              3252
# 1231              25068              0.04486             14962
# 1232              25068              0.03396              4487
# 1233              25068              0.02330              2346
# 1234              25068              0.00000                21
#
#       newconfirmed_proportion
# 1230                 0.129727
# 1231                 0.596857
# 1232                 0.178993
# 1233                 0.093585
# 1234                 0.000838

# %%
# Extract unique dates
dates = covid_df['date'].unique()
date_lst = []
# Change dates to datetime
for d in dates:
    date_lst.append(datetime.strptime(d, '%Y-%m-%d').date())

# %%
important_dates_lst = ['2020-05-12', '2020-05-18', '2020-06-12', '2020-07-13', '2020-09-22', '2020-10-23', '2020-10-28', '2020-11-16', '2020-11-21', '2020-11-27', '2020-12-06']
two_weeks_later_lst = ['2020-05-27', '2020-06-01', '2020-06-26', '2020-07-27', '2020-10-06', '2020-11-06', '2020-11-11', '2020-11-30', '2020-12-05', '2020-12-11', '2020-12-20']
important_dates = []
two_weeks_later = []
for d in range(len(important_dates_lst)):
    important_dates.append(datetime.strptime(important_dates_lst[d], '%Y-%m-%d').date())
    two_weeks_later.append(datetime.strptime(two_weeks_later_lst[d], '%Y-%m-%d').date())

# %%
print(f'Important Dates: {important_dates}\nTwo Weeks Later: {two_weeks_later}')
# Out:
# Important Dates: [datetime.date(2020, 5, 12), datetime.date(2020, 5, 18), datetime.date(2020, 6, 12), datetime.date(2020, 7, 13), datetime.date(2020, 9, 22), datetime.date(2020, 10, 23), datetime.date(2020, 10, 28), datetime.date(2020, 11, 16), datetime.date(2020, 11, 21), datetime.date(2020, 11, 27), datetime.date(2020, 12, 6)]
# Two Weeks Later: [datetime.date(2020, 5, 27), datetime.date(2020, 6, 1), datetime.date(2020, 6, 26), datetime.date(2020, 7, 27), datetime.date(2020, 10, 6), datetime.date(2020, 11, 6), datetime.date(2020, 11, 11), datetime.date(2020, 11, 30), datetime.date(2020, 12, 5), datetime.date(2020, 12, 11), datetime.date(2020, 12, 20)]

# %%
labels = important_dates + two_weeks_later[0:7] + two_weeks_later[9:]
for m in range(2020*12+4-1, 2020*12+11):
    labels.append(datetime(m//12, m%12+1, 1).date())

# %%
# Colour Blind Friendly Colours
CB_color_cycle = ['#a65628', '#984ea3', '#4daf4a',
                  '#ff7f00', '#377eb8', '#999999',
                  '#e41a1c', '#f781bf', '#dede00']

# Counter for colours
c = 0

fig, ax = plt.subplots(figsize = (20,12))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
for age in covid_df['age_group'].unique():
    ax.plot(date_lst, covid_df[covid_df['age_group']==age].drop(['date', 'age_group'], axis = 1)['newconfirmed_age'], c = CB_color_cycle[c])
    c +=1
ax.legend(covid_df['age_group'].unique())
ax.set_xlabel('Date', fontsize = 14)
ax.set_ylabel('New Confirmed Cases', fontsize = 14)
plt.text(x=0.5, y=0.85, s="Daily New Confirmed Cases in California", fontsize=18, ha="center", transform=fig.transFigure)
plt.text(x=0.5, y=0.81, s= f"Starting on April 1st, 2020\nBased on Age Group", fontsize=12, ha="center", transform=fig.transFigure)
plt.subplots_adjust(top=0.8, wspace=0.3)
for date in range(len(important_dates)):
    ax.vlines(important_dates[date], ymin = min(covid_df['newconfirmed_age']), ymax = max(covid_df['newconfirmed_age']), colors = 'dimgray', linestyles = 'dashed')
    ax.vlines(two_weeks_later[date], ymin = min(covid_df['newconfirmed_age']), ymax = max(covid_df['newconfirmed_age']), colors = 'darkred', linestyles = 'dotted')

plt.xticks(labels, labels, rotation = 70, fontsize = 12);

# %% [markdown]
# ### Important Dates:
# - March 19th - statewide SIP (2 weeks later - April 2)
# - May 13 - LA beaches reopen (2 weeks later - May 27)
# - May 18 - Newsom changes reopening parameters (more eased) (2 weeks later - June 1)
# - June 12 - indoor businesses like restaurants, retail stores, bars, gyms, and religious services reopen (2 weeks later - June 26)
# - July 13 - bars and indoor dining closed again (some counties close gyms, churches, hair salons, etc) (2 weeks later - July 27)
# - September 22 - nail salons and salons reopen (2 weeks later - October 6)
# - October 23 - State allows nursing home visitors (2 weeks later - November 6)
# - October 28 - San Mateo gyms increase capacity from 10% to 25% (2 weeks later - November 11)
# - November 16 - Nonessential businnesses close and Californians must wear a mask whenever outside their house (2 weeks later - November 30)
# - November 21 - Statewide curfew implemented until December 21 (2 weeks later - December 5)
# - November 27 - LA County imposes new stay-at-home order (2 weeks later - December 11)
# - December 6 - Bay Area (as well as most counties in California) impose new stay-at-home order (2 weeks later - December 20)

# %% [markdown]
# For next time:
# - Hypothesis testing
# - Find the dates when things started to open up (statewide); Create a hypothesis around this- Covid cases were on the rise after the reopen dates

# %% [markdown]
# Blockers:
# - Visuals for the data - I'm not sure which other graphs would be needed
# - Hypothesis testing...? Where to start, is it necessary for this data?

# %% [markdown]
# ## Hypothesis Testing:
#
# $H_0$: Compared to when restrictions were loosened, there was not a decline in positive cases for Covid-19 when the restrictions were implemented.
#
# $H_a$: Compared to when restrictions were loosened, there was a decline in positive cases for Covid-19 when the restrictions were implemented.

# %%
# Chi-squared test for one week before June 12th and 3 weeks after June 12th
# Null is expected proportions of all the groups

# %%
covid_df.columns
# Out:
# Index(['date', 'age_group', 'totalpositive', 'totalcountconfirmed',
#        'newcountconfirmed', 'agegroup_proportion', 'newconfirmed_age',
#        'newconfirmed_proportion'],
#       dtype='object')
